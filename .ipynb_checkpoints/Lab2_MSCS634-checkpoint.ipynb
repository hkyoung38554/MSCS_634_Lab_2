# %%
Lab2_MSCS634.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Lab2_MSCS634.ipynb
#
# NameError: name 'Lab2_MSCS634' is not defined
